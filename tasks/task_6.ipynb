# %% [markdown]
# # Нахождение корней уравнений

# %%
import sys

sys.path.append('..')

# %% [markdown]
# ### 1. Метод последовательного поиска

# %% [markdown]
# ##### Пример:
#
# $$x^3 = -3.23x^2 + 5.54x - 9.84$$
#
# $$x^3 - 3.23x^2 - 5.54x + 9.84 = 0$$

# %% [markdown]
# Нарисуем графики функции:
#
# $$y = x^3$$
#
# и
#
# $$z = -3.23x^2 + 5.54x - 9.84$$

# %%
import numpy as np
from matplotlib import pyplot as plt

x = np.linspace(-6, 5, 10)

y = x**3
z = -3.23*x**2 + 5.54*x - 9.84

plt.xlabel('x')
plt.grid(True)
plt.plot(x, y, label='x^3')
plt.plot(x, z, label='-3.23*x^2 + 5.54*x - 9.84')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# Пусть:
#
# $$f(x) = x^3 - 3.23x^2 - 5.54x + 9.84$$

# %%
from math import log
from modules.equations.single import root_search

def f(x: float): return x**3 - 3.23*x**2 - 5.54*x + 9.84

x1, x2 = root_search(f, -6, 5, 10)

x1, x2
# Out:
# (-6, 4)

# %%
f(x1), f(x2)
# Out:
# (-289.2, 0.0)

# %% [markdown]
# ### 2. Метод бисекции

# %%
from modules.equations.single import bisection

x = bisection(f, -6, 5, 10**-9)

x
# Out:
# -2.000000000203727

# %%
f(x)
# Out:
# -3.948224858163485e-09

# %% [markdown]
# ### 3. Метод Риддера

# %%
from modules.equations.single import ridder

x, iter = ridder(f, -6, 5, 10**-9, 10)

x, iter
# Out:
# (-2.0, 9)

# %%
f(x)
# Out:
# -1.7763568394002505e-15

# %% [markdown]
# ### 4. Метод Ньютона-Рафсона

# %% [markdown]
# $$f'(x) = 3x^2 - 6.46x - 5.54$$

# %%
from modules.equations.single import newton_raphson

def df(x: float): return 3*x**2 - 6.46*x - 5.54

x, iter = newton_raphson(f, df, -6, 5, 10**-9, 10)

x, iter
# Out:
# (-2.0000000000004565, 6)

# %%
f(x)
# Out:
# -8.848033417052648e-12
