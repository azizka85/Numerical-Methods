# %% [markdown]
# # Интерполяция

# %%
import sys

sys.path.append('..')

# %% [markdown]
# ### Пример №1

# %%
import numpy as np
import matplotlib.pyplot as plt
import modules.interpolation.neville as nv
import modules.interpolation.cubic_spline as cs

xd = np.array([0, 0.5, 1, 1.5, 2, 2.5, 3])
yd = np.array([1.8421, 2.4694, 2.4921, 1.9047, 0.8509, -0.4112, -1.5727])

x = np.linspace(0, 3, 20)

n = len(x)

y = np.zeros((n, 2))
k = cs.curvatures(xd, yd)

for i in range(n):
    y[i, 0] = nv.polynom(xd, yd, x[i])
    y[i, 1] = cs.polynom(xd, yd, k, x[i])

plt.plot(xd, yd, 'o', x, y[:, 0], '-', x, y[:, 1], '--')
plt.xlabel('x')
plt.legend(['Data', 'Neville', 'Cubic spline'], loc='lower right')

# %% [markdown]
# ### Пример №2
#
# $𝑦 = \sqrt{𝑥 + 1} − \sqrt{𝑥^2 + 19𝑥 + 123}$,  где 𝑥 ∈ [0, 2]

# %%
xd = np.linspace(0.,2., 5)
yd = np.sqrt(𝑥d + 1) - np.sqrt(xd**2 + 19*xd +123) 

x = np.linspace (0., 2., 20)

n = len(x)

y = np.zeros((n, 2))
k = cs.curvatures(xd, yd)

for i in range(n):
    y[i, 0] = nv.polynom(xd, yd, x[i])
    y[i, 1] = cs.polynom(xd, yd, k, x[i])

plt.plot(xd, yd, 'o', x, y[:, 0], '-', x, y[:, 1], '--')
plt.xlabel('x')
plt.legend(['Data', 'Neville', 'Cubic spline'], loc='lower right')
