# %% [markdown]
# # Итерационные методы решения СЛАУ

# %%
import sys

sys.path.append('..')

# %% [markdown]
# ### 1. Метод Гаусса-Зейделя

# %%
import numpy as np
from modules.slae.solver.iterative.gauss_seidel import gauss_seidel

a = np.array([
    [131., -4., 1.],
    [-4., 131., -4.],
    [1., -4., 131.]
])

b = np.array([-1111., 6666., -1111.])

x, iter = gauss_seidel(a, b, 10**-9, 1000)

print(f'iterations: {iter}')

x
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import numpy as np
#       2 from modules.slae.solver.iterative.gauss_seidel import gauss_seidel
#       4 a = np.array([
#       5     [131., -4., 1.],
#       6     [-4., 131., -4.],
#       7     [1., -4., 131.]
#       8 ])
#
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
# ##### Проверим найденное решение
#
# Если $x$ решение $A * x = b$, то $r = A * x - b = 0$

# %%
r = np.dot(a, x) - b

r
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 r = np.dot(a, x) - b
#       3 r
#
# NameError: name 'np' is not defined

# %% [markdown]
# ### 2. Метод Гаусса-Зейделя c релаксацией

# %%
from modules.slae.solver.iterative.gauss_seidel import gauss_seidel_relax

a = np.array([
    [131., -4., 1.],
    [-4., 131., -4.],
    [1., -4., 131.]
])

b = np.array([-1111., 6666., -1111.])

x, iter = gauss_seidel_relax(a, b, 10**-9, 1000)

print(f'iterations: {iter}')

x
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from modules.slae.solver.iterative.gauss_seidel import gauss_seidel_relax
#       3 a = np.array([
#       4     [131., -4., 1.],
#       5     [-4., 131., -4.],
#       6     [1., -4., 131.]
#       7 ])
#       9 b = np.array([-1111., 6666., -1111.])
#
# File c:\Users\user\Desktop\work space\Numerical-Methods\tasks\..\modules\slae\solver\iterative\gauss_seidel.py:1
# ----> 1 import numpy as np
#       2 import math
#       4 def gauss_seidel(
#       5     a: np.ndarray[np.double, np.double],
#       6     b: np.ndarray[np.double],
#       7     tol: np.double, max_iter: np.uint32
#       8 ) -> tuple[np.ndarray[np.double], np.uint32]:
#
# ModuleNotFoundError: No module named 'numpy'

# %%
r = np.dot(a, x) - b

r
# Out:
# array([ 9.97992800e-11,  2.38632225e-10, -2.16822116e-11])

# %% [markdown]
# ### 3. Метод сопряженных градиентов

# %%
from modules.slae.solver.iterative.conjugate_gradient import conjugate_gradient

a = np.array([
    [131., -4., 1.],
    [-4., 131., -4.],
    [1., -4., 131.]
])

b = np.array([-1111., 6666., -1111.])

x, iter = conjugate_gradient(a, b, 10**-9, 1000)

print(f'iterations: {iter}')

x
# Out:
# iterations: 3
# array([3., 1., 1.])

# %%
r = np.dot(a, x) - b

r
# Out:
# array([ 1.77635684e-15, -8.88178420e-16,  1.77635684e-15])

# %% [markdown]
# ### 4. Метод сопряженных градиентов для разреженной матрицы

# %%
from modules.slae.solver.iterative.conjugate_gradient import conjugate_gradient_sym_triplet

t = [
    [0, 0, 131.],
    [0, 1, -4.],
    [0, 2, 1.],
    [1, 1, 131.],
    [1, 2, -4.],
    [2, 2, 131]
]

b = np.array([4., 10., -10.])

x, iter = conjugate_gradient_sym_triplet(t, b, 10**-9, 1000)

print(f'iterations: {iter}')

x
# Out:
# iterations: 3
# array([ 0.54464286,  1.06696429, -0.73214286])

# %%
from modules.matrix.utils import matrix_sym_triplet_mult_vector

r = matrix_sym_triplet_mult_vector(t, x) - b

r
# Out:
# array([-8.88178420e-16, -1.77635684e-15,  3.55271368e-15])
