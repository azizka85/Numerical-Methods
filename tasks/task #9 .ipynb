# %% [markdown]
# # Подгонка кривой

# %%
import sys

sys.path.append('..')

# %% [markdown]
# ### Пример
# $𝑦 = \sqrt{𝑥 + 1} − \sqrt{𝑥^2 + 19𝑥 + 123}$,  где 𝑥 ∈ [0, 2]

# %%
import numpy as np
import random as rnd
from modules.fitting.poly_fit import poly_fit, std_dev, plot_poly

xd = np.linspace(0., 2., 25)
yd =np.sqrt(𝑥d + 1) - np.sqrt(xd**2 + 19*xd +123) 

for i in range(len(yd)):
    yd[i] = yd[i] + yd[i] * rnd.random() * 0.2

c = poly_fit(xd, yd, 3)

plot_poly(xd, yd, c)

# %%
std_dev(c, xd, yd)
# Out:
# 0.4550881932666422
