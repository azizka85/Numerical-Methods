# %% [markdown]
# # Нахождение корней уравнений

# %%
import sys

sys.path.append('..')

# %% [markdown]
# $$x^4+2x^3-7x^2+3=0$$

# %% [markdown]
# Нарисуем графики функции

# %% [markdown]
# $$y=x^4$$

# %% [markdown]
# $$z=-2x^3+7x^2-3$$

# %% [markdown]
# ### 1. Метод последовательного поиска

# %%
import numpy as np
from matplotlib import pyplot as plt

x = np.linspace(-5, -3, 9)

y = x**4
z = -2*x**3 + 7*x**2 - 3

plt.xlabel('x')
plt.grid(True)
plt.plot(x, y, label='x^4')
plt.plot(x, z, label='-2*X**3+7*X**2-3')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# Пусть:
#
# $$f(x) = x^4+2x^3-7x^2+3 $$

# %%
from math import log
from modules.equations.single import root_search

def f(x: float): return x**4+2*x**3-7*x**2+3

x1, x2 = root_search(f, -5, -3, 0.001)

x1, x2
# Out:
# (-3.7919999999996894, -3.7909999999996895)

# %%
f(x1), f(x2)
# Out:
# (0.056047005671558736, -0.022637576263392134)

# %% [markdown]
# ### 2. Метод бисекции

# %%
from modules.equations.single import bisection

x = bisection(f, -5, -3, 10**-9)

x
# Out:
# -3.791287848725915

# %%
f(x)
# Out:
# 9.816805857099098e-08

# %% [markdown]
# ### 3. Метод Риддера

# %%
from modules.equations.single import ridder

x, iter = ridder(f, -5, -3, 10**-9, 100)

x, iter
# Out:
# (-3.7912878474779204, 12)

# %%
f(x)
# Out:
# 2.842170943040401e-14

# %% [markdown]
# ### 4. Метод Ньютона-Рафсона

# %% [markdown]
# $$f'(x) = 4x^3+6x^2-14x$$

# %%
from modules.equations.single import newton_raphson

def df(x: float): return 4*x**3 + 6*x**2 - 14*x

x, iter = newton_raphson(f, df, -5, -3, 10**-9, 100)

x, iter
# Out:
# (-3.7912878474779386, 4)

# %%
f(x)
# Out:
# 1.4495071809506044e-12
