# %% [markdown]
# # Нахождение корней уравнений

# %%
import sys

sys.path.append('..')

# %% [markdown]
# ### 1. Метод последовательного поиска

# %% [markdown]
# $$xsin(x)+3cos(x)-x = 0$$
# $$x=xsin(x)+3cos(x)$$

# %% [markdown]
# Нарисуем графики функции:
#
# $$y=x$$
#
# и
#
# $$z = xsin(x)+3cos(x)$$

# %%
import numpy as np
from matplotlib import pyplot as plt

x = np.linspace(0, 5, 20)

y = x
z = x*np.sin(x)+3*np.cos(x)

plt.xlabel('x')
plt.grid(True)
plt.plot(x, y, label='ln(x)')
plt.plot(x, z, label='x - 2.5')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# Пусть:
#
# $$f(x) = xsin(x)+3cos(x)-x$$

# %%
from math import sin, cos
from modules.equations.single import root_search

def f(x: float): return x*np.sin(x)+3*np.cos(x)-x

x1, x2 = root_search(f, -10, 10, 0.02)

x1, x2
# Out:
# (-4.7200000000001125, -4.700000000000113)

# %%
f(x1), f(x2)
# Out:
# (0.02296954692507036, -0.03680530093961387)

# %% [markdown]
# ### 2. Метод бисекции

# %%
from modules.equations.single import bisection

x = bisection(f, -10, 10, 10**-9)

x
# Out:
# 1.570796326850541

# %%
f(x)
# Out:
# -1.669329119380336e-10

# %% [markdown]
# ### 3. Метод Риддера

# %%
from modules.equations.single import ridder

x, iter = ridder(f, 0.02, 0.2, 10**-9, 100)

x, iter
# Out:
# (1.5707963267948966, 100)

# %%
f(x)
# Out:
# 2.220446049250313e-16

# %% [markdown]
# ### 4. Метод Ньютона-Рафсона

# %% [markdown]
# $$f'(x) = -2sin(x)+xcos(x) - 1$$

# %%
from modules.equations.single import newton_raphson

def df(x: float): return -2*np.sin(x)+x*np.cos(x) - 1.

x, iter = newton_raphson(f, df, -10, 10, 10**-9, 100)

x, iter
# Out:
# (1.5707963267986722, 5)

# %%
f(x)
# Out:
# -1.1326717341830772e-11
