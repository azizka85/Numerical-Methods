# %% [markdown]
# # Нахождение корней уравнений

# %%
import sys

sys.path.append('..')

# %% [markdown]
# ### 1. Метод последовательного поиска

# %% [markdown]
# ##### Пример:
#
# $$sin(x) = 0.1x$$
#
# $$sin(x) - 0.1x = 0$$

# %% [markdown]
# Нарисуем графики функции:
#
# $$y = sin(x)$$
#
# и
#
# $$z = 0.1x$$

# %%
import numpy as np
from math import pi
from matplotlib import pyplot as plt

x = np.linspace(-2 * np.pi, 2 * np.pi, 200)

y = np.sinh(x) * np.sin(x)
z = 0.1*x

plt.xlabel('x')
plt.grid(True)
plt.plot(x, y, label='sin(x)')
plt.plot(x, z, label='0.1x')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# Пусть:
#
# $$f(x) = sh(x)sin(x)

# %%
from math import sin, cos
from modules.equations.single import root_search

def f(x: float): return np.sinh(x) * np.sin(x)

x1, x2 = root_search(f, -np.pi / 2, np.pi, 0.000002)

x1, x2

# %%
f(x1), f(x2)
# Out:
# (1.132305745610959e-05, -1.1774422162574216e-05)

# %% [markdown]
# ### 2. Метод бисекции

# %%
from modules.equations.single import bisection

x = bisection(f, -np.pi / 2, np.pi, 10**-9)

x
# Out:
# 3.141592653589793

# %%
f(x)
# Out:
# 1.414312668805276e-15

# %% [markdown]
# ### 3. Метод Риддера

# %%
from modules.equations.single import ridder

x, iter = ridder(f,  -np.pi / 2, np.pi, 10**-9, 100)

x, iter
# Out:
# (3.141592653589793, 0)

# %%
f(x)
# Out:
# 1.414312668805276e-15

# %% [markdown]
# ### 4. Метод Ньютона-Рафсона

# %% [markdown]
# $$f'(x) = cos(x) * sh(x) + sin(x) * ch(x)$$

# %%
from modules.equations.single import newton_raphson

def df(x: float): return np.cos(x) * np.sinh(x) + np.sin(x) * np.cosh(x)

x, iter = newton_raphson(f, df, -np.pi / 2, np.pi, 10**-9, 100)

x, iter
# Out:
# (3.141592653589793, 0)

# %%
f(x)
# Out:
# 1.414312668805276e-15
