# %% [markdown]
# # Нахождение корней уравнений

# %%
import sys

sys.path.append('..')

# %% [markdown]
# ### 1. Метод последовательного поиска

# %% [markdown]
# ##### Пример:
#
# $$sin(x) = 0.1x$$
#
# $$sin(x) - 0.1x = 0$$

# %% [markdown]
# Нарисуем графики функции:
#
# $$y = sin(x)$$
#
# и
#
# $$z = 0.1x$$

# %%
import numpy as np
from math import pi
from matplotlib import pyplot as plt

x = np.linspace(2, 3, 20)

y = np.sin(x)
z = 0.1*x

plt.xlabel('x')
plt.grid(True)
plt.plot(x, y, label='sin(x)')
plt.plot(x, z, label='0.1x')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# Пусть:
#
# $$f(x) = sin(x) - 0.1x$$

# %%
from math import sin, cos
from modules.equations.single import root_search

def f(x: float): return sin(x) - 0.1*x

x1, x2 = root_search(f, 2, 3, 0.000002)

x1, x2
# Out:
# (2.852339999929881, 2.8523419999298807)

# %%
f(x1), f(x2)
# Out:
# (2.0052692840666353e-06, -1.1164591273704616e-07)

# %% [markdown]
# ### 2. Метод бисекции

# %%
from modules.equations.single import bisection

x = bisection(f, 2, 3, 10**-9)

x
# Out:
# 2.8523418940603733

# %%
f(x)
# Out:
# 4.1250042270846166e-10

# %% [markdown]
# ### 3. Метод Риддера

# %%
from modules.equations.single import ridder

x, iter = ridder(f, 2, 3, 10**-9, 100)

x, iter
# Out:
# (2.852341894450092, 11)

# %%
f(x)
# Out:
# -1.1102230246251565e-16

# %% [markdown]
# ### 4. Метод Ньютона-Рафсона

# %% [markdown]
# $$f'(x) = cos(x) - 0.1$$

# %%
from modules.equations.single import newton_raphson

def df(x: float): return cos(x) - 0.1

x, iter = newton_raphson(f, df, 2, 3, 10**-9, 100)

x, iter
# Out:
# (2.852341894450092, 4)

# %%
f(x)
# Out:
# -1.1102230246251565e-16
