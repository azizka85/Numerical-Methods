# %% [markdown]
# # Собственные значения и вектора матрицы

# %% [markdown]
# ##### Нахождение собственного значения и вектора матрицы

# %%
import numpy as np

a = np.array([[9, -4, 1], [-4, 9, -4], [1, -4, 9] ])

eigenvalues, eigenvectors = np.linalg.eig(a)

print("Собственные значения:")
print(eigenvalues)

print("\nСобственные векторы:")
print(eigenvectors)
# Out:
# Собственные значения:
# [15.17890835  8.          3.82109165]
#
# Собственные векторы:
# [[-5.21546999e-01  7.07106781e-01  4.77481651e-01]
#  [ 6.75261027e-01 -3.54867315e-16  7.37578840e-01]
#  [-5.21546999e-01 -7.07106781e-01  4.77481651e-01]]

# %% [markdown]
# ##### Нормы собственных векторов

# %%
m = len(eigenvalues)

for i in range(m):
    print(f'Норма собственного вектора для λ = {eigenvalues[i]}, есть {np.dot(eigenvectors[:, i], eigenvectors[:, i])}')
# Out:
# Норма собственного вектора для λ = 15.178908345800279, есть 1.0
# Норма собственного вектора для λ = 7.999999999999998, есть 0.9999999999999999
# Норма собственного вектора для λ = 3.821091654199726, есть 0.9999999999999999

# %% [markdown]
# ##### Проверим найденные собственные значения
#
# $$A \cdot x = \lambda \cdot x$$
#
# $$(A - \lambda I) \cdot x = 0$$

# %%
n = len(eigenvectors[0])

for i in range(m):
    b = np.diag([eigenvalues[i]] * n)
    c = a - b

    print('---')
    print(f'Проверка собственного значения λ = {eigenvalues[i]}')
    print(f'Детерминант матрицы A - λI = {np.linalg.det(c)}')
    print(f'(A - λI)x = {np.dot(c, eigenvectors[:, i])}')
# Out:
# ---
# Проверка собственного значения λ = 15.178908345800279
# Детерминант матрицы A - λI = -4.590829058216356e-13
# (A - λI)x = [ 2.66453526e-15 -3.55271368e-15  2.92724772e-15]
# ---
# Проверка собственного значения λ = 7.999999999999998
# Детерминант матрицы A - λI = -5.329070518200769e-14
# (A - λI)x = [ 2.44249065e-15  4.44089210e-16 -3.48286399e-17]
# ---
# Проверка собственного значения λ = 3.821091654199726
# Детерминант матрицы A - λI = 0.0
# (A - λI)x = [ 3.21964677e-15 -1.77635684e-15 -4.95622730e-16]
