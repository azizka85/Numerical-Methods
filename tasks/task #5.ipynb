# %% [markdown]
# # Задание №5
# # Собственные значения и вектора матрицы

# %% [markdown]
# ##### Нахождение собственного значения и вектора матрицы

# %%
import numpy as np

a = np.array([[7, -3, 1], [-3, 7, -3], [1 , -3, 7]])

eigenvalues, eigenvectors = np.linalg.eig(a)

print("Собственные значения:")
print(eigenvalues)

print("\nСобственные векторы:")
print(eigenvectors)
# Out:
# Собственные значения:
# [11.77200187  6.          3.22799813]
#
# Собственные векторы:
# [[-5.28450837e-01  7.07106781e-01  4.69829451e-01]
#  [ 6.64439182e-01 -2.57227443e-16  7.47342340e-01]
#  [-5.28450837e-01 -7.07106781e-01  4.69829451e-01]]

# %% [markdown]
# ##### Нормы собственных векторов

# %%
m = len(eigenvalues)

for i in range(m):
    print(f'Норма собственного вектора для λ = {eigenvalues[i]}, есть {np.dot(eigenvectors[:, i], eigenvectors[:, i])}')
# Out:
# Норма собственного вектора для λ = 11.772001872658768, есть 1.0000000000000002
# Норма собственного вектора для λ = 5.999999999999998, есть 1.0
# Норма собственного вектора для λ = 3.2279981273412353, есть 0.9999999999999998

# %% [markdown]
# ##### Проверим найденные собственные значения
#
# $$A \cdot x = \lambda \cdot x$$
#
# $$(A - \lambda I) \cdot x = 0$$

# %%
n = len(eigenvectors[0])

for i in range(m):
    b = np.diag([eigenvalues[i]] * n)
    c = a - b

    print('---')
    print(f'Проверка собственного значения λ = {eigenvalues[i]}')
    print(f'Детерминант матрицы A - λI = {np.linalg.det(c)}')
    print(f'(A - λI)x = {np.dot(c, eigenvectors[:, i])}')
# Out:
# ---
# Проверка собственного значения λ = 11.772001872658768
# Детерминант матрицы A - λI = -9.996806628440212e-14
# (A - λI)x = [-1.11022302e-16 -3.21964677e-15  3.39467191e-16]
# ---
# Проверка собственного значения λ = 5.999999999999998
# Детерминант матрицы A - λI = -2.8421709430404045e-14
# (A - λI)x = [ 1.55431223e-15  9.99200722e-16 -9.23007060e-16]
# ---
# Проверка собственного значения λ = 3.2279981273412353
# Детерминант матрицы A - λI = -1.47721934559831e-14
# (A - λI)x = [-1.66533454e-16 -1.11022302e-15  3.04934005e-17]
