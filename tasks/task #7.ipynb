# %% [markdown]
# # Нахождение корней уравнений

# %%
import sys

sys.path.append('..')

# %% [markdown]
# ### Метод Ньютона-Рафсона для системы уравнении

# %% [markdown]
# ##### Пример:
#
# $$4x^2-2x-3y^2-y-76=0$$
#
# $$x - y - 3 = 0$$

# %%
import numpy as np
from math import sin, log
from modules.equations.system import newton_raphson_system

def f(x: np.ndarray[np.double]) -> np.ndarray[np.double]:
    fx = np.zeros(len(x))

    fx[0] = 4*x[0]**2 - 2*x[0] - 3*x[1]**2 - x[1] - 76    
    fx[1] = x[0] - x[1] - 3.

    return fx

x = np.array([1., 1.])

x, iter = newton_raphson_system(f, x, 10**-4, 10**-9, 100)

x, iter
# Out:
# (array([-20., -23.]), 8)

# %%
f(x)
# Out:
# array([2.27373675e-13, 0.00000000e+00])
