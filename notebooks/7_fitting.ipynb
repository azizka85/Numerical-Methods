# %% [markdown]
# # Подгонка кривой

# %%
import sys

sys.path.append('..')

# %% [markdown]
# ### Пример
#
# $y = x \cdot ln(x)$, где $x \in [1, 10]$

# %%
import numpy as np
import random as rnd
from modules.fitting.poly_fit import poly_fit, std_dev, plot_poly

xd = np.linspace(1., 10., 30)
yd = xd * np.log(xd)

for i in range(len(yd)):
    yd[i] = yd[i] + yd[i] * rnd.random() * 0.1

c = poly_fit(xd, yd, 3)

plot_poly(xd, yd, c)

# %%
std_dev(c, xd, yd)
# Out:
# 0.37016227861246453
